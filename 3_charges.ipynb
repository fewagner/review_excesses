# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

from colors import colors

# %config InlineBackend.figure_formats = ['svg']
mpl.rcParams.update({'font.size': 12})

# %%
# (Diagram of different charge contributions a la Du et al paper)

# %% [markdown]
# # calc lines

# %%
data = {}

# fill here ...

# %% [markdown]
# # plot

# %%
fig, ax = plt.subplots(1, 1, dpi=300, figsize=(6,5))

# ---------------------------------------------
# contributions
# ---------------------------------------------

# plot contributions

# TODO plt.plot(data[...], data[...], ...)

# specs
ax.legend(frameon=False, loc='upper left')
ax.set_xscale('log')
ax.set_yscale('log')
# ax.set_xlim(3, 1000)
# ax.set_ylim(1e-4, 1e5)
ax.set_ylabel('y label')
ax.set_xlabel('x label')

# ---------------------------------------------
# globals 
# ---------------------------------------------

plt.tight_layout()
plt.savefig('plots/fig3.png')
plt.show()
# Out:
# /var/folders/0y/_zyrlyfn1412ysy20pvh2r8c0000gn/T/ipykernel_8988/2158253953.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(frameon=False, loc='upper left')
